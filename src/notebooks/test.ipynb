# %%
import csv

import forex_factory
from pytrader import li_gemini_token

# %%
import  pandas as pd
import toon_python as toon
import json
import csv
import pandas as pd

# %%
from llm_chart_analysis import LLMChartAnalysis

li_gemini_token = [
    'AIzaSyCq3ec2tys-PoOuRIJHOwEBir2XcPDU0XQ',  # mas5862
    'AIzaSyC8PNPA7GOhfMSYXB5d1MEoVMxU-Fg6X3I',  # maspytradelog
    'AIzaSyCxbDmG_9KgaNWqcIJ8TrAk3zZvlw36Hro'  # m.strevig2014
    ]
model = 'gemini-2.5-pro'
model = 'gemini-3-pro-preview'

from google import genai
from google.genai import types

# LLM = LLMChartAnalysis(
#     li_gemini_token=li_gemini_token,
#     model=model
# )

client = genai.Client(api_key=li_gemini_token[0])

response = client.models.generate_content(
    model=model,
    contents="Hello",
    config=types.GenerateContentConfig(
        system_instruction="You are an assistant",
        temperature=0.1
    )
)
print(response)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[12], line 21
#      14 # LLM = LLMChartAnalysis(
#      15 #     li_gemini_token=li_gemini_token,
#      16 #     model=model
#      17 # )
#      19 client = genai.Client(api_key=li_gemini_token[0])
# ---> 21 response = client.models.generate_content(
#      22     model=model,
#      23     contents="Hello",
#      24     config=types.GenerateContentConfig(
#      25         system_instruction="You are an assistant",
#      26         temperature=0.1
#      27     )
#      28 )
#      29 print(response)
#
# File ~\PycharmProjects\Trading\.venv\Lib\site-packages\google\genai\models.py:6138, in Models.generate_content(self, model, contents, config)
#    6136 while remaining_remote_calls_afc > 0:
#    6137   i += 1
# -> 6138   response = self._generate_content(
# ...
